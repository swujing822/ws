# %%
import os
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px

def plot_orderbook_with_arbitrage(df: pd.DataFrame, symbol: str, save_dir: str = "arb_charts_interactive"):
    df["datetime"] = pd.to_datetime(df["timestamp"], unit="ms")
    exchanges = df["exchange"].unique()
    color_map = px.colors.qualitative.Plotly

    fig = go.Figure()

    # 📈 绘制 bid1 和 ask1
    for i, ex in enumerate(exchanges):
        sub = df[df["exchange"] == ex]
        fig.add_trace(go.Scatter(
            x=sub["datetime"], y=sub["bid1_price"],
            mode="lines", name=f"{ex} bid1",
            line=dict(color=color_map[i % len(color_map)], dash="dash"), opacity=0.7
        ))
        fig.add_trace(go.Scatter(
            x=sub["datetime"], y=sub["ask1_price"],
            mode="lines", name=f"{ex} ask1",
            line=dict(color=color_map[i % len(color_map)], dash="solid"), opacity=0.7
        ))

    # 📉 套利计算
    arbs = []
    for time, group in df.groupby("datetime"):
        bid_row = group.loc[group["bid1_price"].idxmax()]
        ask_row = group.loc[group["ask1_price"].idxmin()]
        spread = bid_row["bid1_price"] - ask_row["ask1_price"]
        if spread > 0:
            pct = (spread / ask_row["ask1_price"]) * 100
            arbs.append({
                "time": time, "spread_pct": pct,
                "buy": ask_row["exchange"], "sell": bid_row["exchange"]
            })

    arbs_df = pd.DataFrame(arbs)
    fig.add_trace(go.Scatter(
        x=arbs_df["time"], y=arbs_df["spread_pct"],
        mode="lines", name="Arbitrage %",
        line=dict(color="purple", width=2)
    ))

    # 📍 最大套利点
    if not arbs_df.empty:
        max_row = arbs_df.loc[arbs_df["spread_pct"].idxmax()]
        fig.add_trace(go.Scatter(
            x=[max_row["time"]], y=[max_row["spread_pct"]],
            mode="markers+text", name="Max Arbitrage",
            text=[f"{max_row['spread_pct']:.4f}%\nBuy:{max_row['buy']}\nSell:{max_row['sell']}"],
            marker=dict(color="red", size=10), textposition="top center"
        ))

    fig.update_layout(
        title=f"{symbol} Orderbook & Arbitrage",
        xaxis_title="Time", yaxis_title="Price / Spread %",
        hovermode="x unified", legend=dict(orientation="h")
    )

    os.makedirs(save_dir, exist_ok=True)
    html_path = os.path.join(save_dir, f"{symbol}.html")
    fig.write_html(html_path)
    print(f"✅ 可交互图已保存：{html_path}")

# 📂 主流程：批量处理所有 CSV
csv_dir = "../csv_orderbooks_symbol"
for fname in os.listdir(csv_dir):
    if fname.endswith(".csv"):
        symbol = os.path.splitext(fname)[0]
        try:
            df = pd.read_csv(os.path.join(csv_dir, fname))
            plot_orderbook_with_arbitrage(df, symbol)
        except Exception as e:
            print(f"⚠️ 处理 {fname} 时出错：{e}")
# Out:
# ✅ 可交互图已保存：arb_charts_interactive/ob_AERGO_USDT_USDT.html
# ✅ 可交互图已保存：arb_charts_interactive/ob_1INCH_USDT_USDT.html
# ✅ 可交互图已保存：arb_charts_interactive/ob_ACH_USDT_USDT.html
# ✅ 可交互图已保存：arb_charts_interactive/ob_AEVO_USDT_USDT.html
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 75
#      73 try:
#      74     df = pd.read_csv(os.path.join(csv_dir, fname))
# ---> 75     plot_orderbook_with_arbitrage(df, symbol)
#      76 except Exception as e:
#      77     print(f"⚠️ 处理 {fname} 时出错：{e}")
#
# Cell In[1], line 31, in plot_orderbook_with_arbitrage(df, symbol, save_dir)
#      29 for time, group in df.groupby("datetime"):
#      30     bid_row = group.loc[group["bid1_price"].idxmax()]
# ---> 31     ask_row = group.loc[group["ask1_price"].idxmin()]
#      32     spread = bid_row["bid1_price"] - ask_row["ask1_price"]
#      33     if spread > 0:
#
# File /workspaces/ws/.venv/lib/python3.12/site-packages/pandas/core/series.py:2686, in Series.idxmin(self, axis, skipna, *args, **kwargs)
#    2681 with warnings.catch_warnings():
#    2682     # TODO(3.0): this catching/filtering can be removed
#    2683     # ignore warning produced by argmin since we will issue a different
#    2684     #  warning for idxmin
#    2685     warnings.simplefilter("ignore")
# -> 2686     i = self.argmin(axis, skipna, *args, **kwargs)
#    2688 if i == -1:
#    2689     # GH#43587 give correct NA value for Index.
#    2690     warnings.warn(
#    2691         f"The behavior of {type(self).__name__}.idxmin with all-NA "
#    2692         "values, or any-NA and skipna=False, is deprecated. In a future "
#    (...)   2695         stacklevel=find_stack_level(),
#    2696     )
#
# File /workspaces/ws/.venv/lib/python3.12/site-packages/pandas/core/base.py:789, in IndexOpsMixin.argmin(self, axis, skipna, *args, **kwargs)
#     787         return delegate.argmin()
#     788 else:
# --> 789     result = nanops.nanargmin(delegate, skipna=skipna)
#     790     if result == -1:
#     791         warnings.warn(
#     792             f"The behavior of {type(self).__name__}.argmax/argmin "
#     793             "with skipna=False and NAs, or with all-NAs is deprecated. "
#    (...)    796             stacklevel=find_stack_level(),
#     797         )
#
# File /workspaces/ws/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:1193, in nanargmin(values, axis, skipna, mask)
#    1155 def nanargmin(
#    1156     values: np.ndarray,
#    1157     *,
#    (...)   1160     mask: npt.NDArray[np.bool_] | None = None,
#    1161 ) -> int | np.ndarray:
#    1162     """
#    1163     Parameters
#    1164     ----------
#    (...)   1191     array([0, 0, 1, 1])
#    1192     """
# -> 1193     values, mask = _get_values(values, True, fill_value_typ="+inf", mask=mask)
#    1194     result = values.argmin(axis)
#    1195     # error: Argument 1 to "_maybe_arg_null_out" has incompatible type "Any |
#    1196     # signedinteger[Any]"; expected "ndarray[Any, Any]"
#
# File /workspaces/ws/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:294, in _get_values(values, skipna, fill_value, fill_value_typ, mask)
#     260 """
#     261 Utility to get the values view, mask, dtype, dtype_max, and fill_value.
#     262
#    (...)    288     Mask for values, if deemed necessary to compute
#     289 """
#     290 # In _get_values is only called from within nanops, and in all cases
#     291 #  with scalar fill_value.  This guarantee is important for the
#     292 #  np.where call below
# --> 294 mask = _maybe_get_mask(values, skipna, mask)
#     296 dtype = values.dtype
#     298 datetimelike = False
#
# File /workspaces/ws/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:248, in _maybe_get_mask(values, skipna, mask)
#     245         return None
#     247     if skipna or values.dtype.kind in "mM":
# --> 248         mask = isna(values)
#     250 return mask
#
# File /workspaces/ws/.venv/lib/python3.12/site-packages/pandas/core/dtypes/missing.py:178, in isna(obj)
#     101 def isna(obj: object) -> bool | npt.NDArray[np.bool_] | NDFrame:
#     102     """
#     103     Detect missing values for an array-like object.
#     104
#    (...)    176     Name: 1, dtype: bool
#     177     """
# --> 178     return _isna(obj)
#
# File /workspaces/ws/.venv/lib/python3.12/site-packages/pandas/core/dtypes/missing.py:207, in _isna(obj, inf_as_na)
#     205     return False
#     206 elif isinstance(obj, (np.ndarray, ABCExtensionArray)):
# --> 207     return _isna_array(obj, inf_as_na=inf_as_na)
#     208 elif isinstance(obj, ABCIndex):
#     209     # Try to use cached isna, which also short-circuits for integer dtypes
#     210     #  and avoids materializing RangeIndex._values
#     211     if not obj._can_hold_na:
#
# File /workspaces/ws/.venv/lib/python3.12/site-packages/pandas/core/dtypes/missing.py:300, in _isna_array(values, inf_as_na)
#     298         result = ~np.isfinite(values)
#     299     else:
# --> 300         result = np.isnan(values)
#     302 return result
#
# KeyboardInterrupt:
